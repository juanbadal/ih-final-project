# %%
import sys
sys.path.append('c:\\Users\\Juan\\Documents\\Ironhack\\Week_9\\ih-final-project\\src\\lib')

# %%
import functions

functions.demo_image_fe_pred(image_filename='juan-happy.png', model_filename='ResNet50_model.h5')
# Out:
# 1/1 [==============================] - 3s 3s/step
